# %%
from fpdf import FPDF

# สร้าง PDF
pdf = FPDF()
pdf.set_auto_page_break(auto=True, margin=15)
pdf.add_page()
pdf.set_font("Arial", style='', size=12)

# ส่วนหัวของ Resume
pdf.set_font("Arial", style='B', size=16)
pdf.cell(200, 10, "RESUME", ln=True, align='C')
pdf.ln(5)

# ข้อมูลส่วนตัว
pdf.set_font("Arial", style='B', size=14)
pdf.cell(200, 10, "ณัฐวัฒน์ เรืองขำ (Natthawat Ruangkhum)", ln=True, align='C')
pdf.set_font("Arial", size=12)
pdf.cell(200, 10, "ที่อยู่: SK Condo, 100/76 ห้อง 614 หมู่ 5 ต.นามะตูม อ.พนัสนิคม จ.ชลบุรี 20140", ln=True, align='C')
pdf.cell(200, 10, "โทรศัพท์: 088-293-8625 | อีเมล: natthawat.derb@gmail.com", ln=True, align='C')
pdf.cell(200, 10, "LINE ID: d.theimp", ln=True, align='C')
pdf.ln(10)

# สรุปคุณสมบัติ
pdf.set_font("Arial", style='B', size=12)
pdf.cell(0, 10, "สรุปคุณสมบัติ (Professional Summary)", ln=True)
pdf.set_font("Arial", size=11)
summary = [
    "✅ IT Support & System Administrator มากกว่า 4 ปี เชี่ยวชาญด้าน IT Helpdesk, Network Administration",
    "✅ มีทักษะ Windows Server, QNAP NAS, MikroTik SwOS, Firewall Configuration",
    "✅ ประสบการณ์ดูแล Web Hosting, Email Hosting, SEO, Digital Marketing",
    "✅ แก้ไขปัญหาทางเทคนิคอย่างรวดเร็ว และมีทักษะการสื่อสารที่ดี",
    "✅ พัฒนาทักษะ Full Stack Development เพื่อเพิ่มศักยภาพในสายงาน IT"
]
for line in summary:
    pdf.cell(0, 7, line, ln=True)

pdf.ln(5)

# ลักษณะงานที่ต้องการ
pdf.set_font("Arial", style='B', size=12)
pdf.cell(0, 10, "ลักษณะงานที่ต้องการ (Job Preferences)", ln=True)
pdf.set_font("Arial", size=11)
pdf.cell(0, 7, "🔹 ตำแหน่งที่ต้องการ: IT Support | System Administrator | Junior Web Developer", ln=True)
pdf.cell(0, 7, "🔹 เงินเดือนที่ต้องการ: 20,000 - 25,000 บาท", ln=True)
pdf.cell(0, 7, "🔹 วันที่สามารถเริ่มงานได้: ภายใน 1 เดือน", ln=True)
pdf.cell(0, 7, "🔹 สถานที่ปฏิบัติงานที่ต้องการ: ชลบุรี", ln=True)

pdf.ln(5)

# ทักษะ
pdf.set_font("Arial", style='B', size=12)
pdf.cell(0, 10, "ทักษะและความสามารถ (Skills & Competencies)", ln=True)
pdf.set_font("Arial", size=11)
skills = [
    "🖥️ IT Infrastructure: QNAP NAS, MikroTik SwOS, Firewall Configuration",
    "🔧 Network Administration: VPN, Firewall, Router (TOT, AIS)",
    "📡 Remote Support: AnyDesk, TeamViewer",
    "📌 Software & OS Management: Windows 10/11, Linux, Microsoft Office, Antivirus",
    "💡 Programming: HTML, CSS, JavaScript, Python (พื้นฐาน)",
    "📊 Database & Cloud: GitHub, Cloud Computing (พื้นฐาน)"
]
for skill in skills:
    pdf.cell(0, 7, skill, ln=True)

# บันทึกไฟล์ PDF
pdf_filename = "/mnt/data/Natthawat_Resume.pdf"
pdf.output(pdf_filename)

pdf_filename
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-62dcbcd0e544> in <cell line: 0>()
# ----> 1 from fpdf import FPDF
#       2
#       3 # สร้าง PDF
#       4 pdf = FPDF()
#       5 pdf.set_auto_page_break(auto=True, margin=15)
#
# ModuleNotFoundError: No module named 'fpdf'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
